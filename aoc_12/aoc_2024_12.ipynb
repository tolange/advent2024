# %%
import numpy as np

# %%
testinput = [
"RRRRIICCFF",
"RRRRIICCCF",
"VVRRRCCFFF",
"VVRCCCJFFF",
"VVVVCJJCFE",
"VVIVCCJJEE",
"VVIIICJJEE",
"MIIIIIJJEE",
"MIIISIJEEE",
"MMMISSJEEE",
]

# %%
class Node:
    def __init__(self, posx, posy, plant):
        self.posx = posx 
        self.posy = posy
        self.plant = plant
        self.partners = { self }
        self.needfence = 0
    def __eq__(self, other):
        return self.posx == other.posx and self.posy == other.posy and self.plant == other.plant
    def __hash__(self):
        return hash(str(self.posx) + str(self.posy) + self.plant)
    def getPartners(self):
        return self.partners
    def getPlant(self):
        return self.plant
    def addFence(self):
        self.needfence += 1
    def getFence(self):
        return self.needfence
    def addPartner(self, partner):
        newpartners = partner.partners
        newpartners = newpartners.union(self.partners)
        for p in newpartners:
            p.partners = newpartners

def convertinput(ipt):
    m = {}
    for i, l in enumerate(ipt):
        m[i] = {}
        for ic, c in enumerate(l):
            m[i][ic] = Node(ic, i, c)
            #m[i][ic].partners.add(m[i][ic])
    return m

def connectInput(ipt):
    for y in ipt:
        for x in ipt[y]:
            for d in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
                testpos = np.array((y, x)) + np.array(d)
                crop = ipt[y][x].getPlant()
                if 0<= testpos[0] < len(ipt) and 0<= testpos[1] < len(ipt[y]):
                    if crop == ipt[testpos[0]][testpos[1]].getPlant():
                        ipt[y][x].addPartner( ipt[testpos[0]][testpos[1]] )
                    else: ipt[y][x].addFence()
                else: ipt[y][x].addFence()
    return ipt

def removeifExists(ipt, node):
    if node.posy in ipt and node.posx in ipt[node.posy]:
        ipt[node.posy].pop(node.posx)
        if len(ipt[node.posy])==0:
            ipt.pop(node.posy)

def countSides(plot):
    LeftNothing = []
    RightNothing = []
    TopNothing = []
    BottomNothing = []
    for p in plot:
        left, right, top, bottom = [None, None, None, None]
        x, y = p.posx, p.posy
        for p2 in plot:
            x2, y2 = p2.posx, p2.posy
            if y==y2 and x2==x-1: left=p
            if y==y2 and x2==x+1: right=p
            if x==x2 and y2==y-1: top=p
            if x==x2 and y2==y+1: bottom=p
        if not left: LeftNothing.append(p)
        if not right: RightNothing.append(p)
        if not top: TopNothing.append(p)
        if not bottom: BottomNothing.append(p)
    sides = 0
    LeftNothing.sort(key=lambda p: p.posy)
    for y in LeftNothing:
        count = True
        x = y.posx
        for y2 in LeftNothing:
            if x == y2.posx and y.posy - 1 == y2.posy: count=False
        if count: sides+=1
    RightNothing.sort(key=lambda p: p.posy)
    for y in RightNothing:
        count = True
        x = y.posx
        for y2 in RightNothing:
            if x == y2.posx and y.posy - 1 == y2.posy: count=False
        if count: sides+=1
    TopNothing.sort(key=lambda p: p.posx)
    for x in TopNothing:
        count = True
        y = x.posy
        for x2 in TopNothing:
            if y == x2.posy and x.posx - 1 == x2.posx: count=False
        if count: sides+=1
    BottomNothing.sort(key=lambda p: p.posx)
    for x in BottomNothing:
        count = True
        y = x.posy
        for x2 in BottomNothing:
            if y == x2.posy and x.posx - 1 == x2.posx: count=False
        if count: sides+=1
    return sides
    
def findPlot(ipt):
    if len(ipt) == 0: return []
    iptc = ipt.copy()
    plot = set()
    plotroot = None
    for y in iptc:
        for x in iptc[y]:
            #found crop
            plotroot = iptc[y][x]
            break
        break
    # add to plot and remove it from map
    if plotroot:
        fence = 0
        plot.add(plotroot)
        removeifExists(iptc, plotroot)
        for p in plotroot.getPartners():
            fence += p.getFence()
            plot.add(p)
            removeifExists(iptc, p)
        return [ [ plotroot.getPlant(), fence, len(plot), plot ] ] + findPlot(iptc)
            
def findAllPlots(ipt):
    plots = findPlot(ipt)
    totalvalue = 0
    newtotalvalue = 0
    for p in plots:
        if len(p) > 0:
            value = p[1]*p[2]
            newFence = countSides(p[3])
            newprize = newFence*p[2]
            totalvalue += value
            newtotalvalue += newprize
            print("         type: "+p[0], "size: "+str(p[2]), "fence: "+str(p[1]), "prize: "+str(value))
            print("                newfence: " +str(newFence), "newprize: "+str(newprize))
    print("total prize: ", str(totalvalue))
    print("new total prize: ", str(newtotalvalue))

# %%
findAllPlots(connectInput(convertinput(testinput)))
# Out:
#          type: R size: 12 fence: 18 prize: 216
#                 newfence: 10 newprize: 120
#          type: I size: 4 fence: 8 prize: 32
#                 newfence: 4 newprize: 16
#          type: C size: 14 fence: 28 prize: 392
#                 newfence: 22 newprize: 308
#          type: F size: 10 fence: 18 prize: 180
#                 newfence: 12 newprize: 120
#          type: V size: 13 fence: 20 prize: 260
#                 newfence: 10 newprize: 130
#          type: J size: 11 fence: 20 prize: 220
#                 newfence: 12 newprize: 132
#          type: C size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: E size: 13 fence: 18 prize: 234
#                 newfence: 8 newprize: 104
#          type: I size: 14 fence: 22 prize: 308
#                 newfence: 16 newprize: 224
#          type: M size: 5 fence: 12 prize: 60
#                 newfence: 6 newprize: 30
#          type: S size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
# total prize:  1930
# new total prize:  1206

# %%
ipt = [l.strip("\n") for l in open("input.txt")]

# %%
findAllPlots(connectInput(convertinput(ipt)))
# Out:
#          type: L size: 116 fence: 94 prize: 10904
#                 newfence: 46 newprize: 5336
#          type: F size: 93 fence: 70 prize: 6510
#                 newfence: 44 newprize: 4092
#          type: I size: 54 fence: 52 prize: 2808
#                 newfence: 36 newprize: 1944
#          type: V size: 83 fence: 60 prize: 4980
#                 newfence: 42 newprize: 3486
#          type: Z size: 18 fence: 28 prize: 504
#                 newfence: 18 newprize: 324
#          type: E size: 78 fence: 62 prize: 4836
#                 newfence: 34 newprize: 2652
#          type: N size: 4 fence: 10 prize: 40
#                 newfence: 6 newprize: 24
#          type: K size: 82 fence: 60 prize: 4920
#                 newfence: 36 newprize: 2952
#          type: A size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: R size: 37 fence: 34 prize: 1258
#                 newfence: 16 newprize: 592
#          type: P size: 148 fence: 82 prize: 12136
#                 newfence: 46 newprize: 6808
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: I size: 45 fence: 44 prize: 1980
#                 newfence: 22 newprize: 990
#          type: L size: 85 fence: 60 prize: 5100
#                 newfence: 34 newprize: 2890
#          type: U size: 108 fence: 64 prize: 6912
#                 newfence: 38 newprize: 4104
#          type: O size: 106 fence: 62 prize: 6572
#                 newfence: 30 newprize: 3180
#          type: S size: 35 fence: 34 prize: 1190
#                 newfence: 22 newprize: 770
#          type: D size: 71 fence: 52 prize: 3692
#                 newfence: 24 newprize: 1704
#          type: Z size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: L size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: R size: 178 fence: 112 prize: 19936
#                 newfence: 68 newprize: 12104
#          type: X size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: W size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: H size: 77 fence: 64 prize: 4928
#                 newfence: 44 newprize: 3388
#          type: U size: 60 fence: 46 prize: 2760
#                 newfence: 26 newprize: 1560
#          type: Y size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: O size: 18 fence: 26 prize: 468
#                 newfence: 16 newprize: 288
#          type: K size: 76 fence: 64 prize: 4864
#                 newfence: 42 newprize: 3192
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 34 fence: 44 prize: 1496
#                 newfence: 36 newprize: 1224
#          type: S size: 88 fence: 82 prize: 7216
#                 newfence: 54 newprize: 4752
#          type: W size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: X size: 112 fence: 84 prize: 9408
#                 newfence: 64 newprize: 7168
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Z size: 76 fence: 78 prize: 5928
#                 newfence: 54 newprize: 4104
#          type: X size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: H size: 8 fence: 16 prize: 128
#                 newfence: 14 newprize: 112
#          type: S size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: K size: 67 fence: 70 prize: 4690
#                 newfence: 44 newprize: 2948
#          type: X size: 6 fence: 14 prize: 84
#                 newfence: 10 newprize: 60
#          type: I size: 19 fence: 28 prize: 532
#                 newfence: 20 newprize: 380
#          type: I size: 6 fence: 12 prize: 72
#                 newfence: 6 newprize: 36
#          type: W size: 105 fence: 64 prize: 6720
#                 newfence: 42 newprize: 4410
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: M size: 6 fence: 10 prize: 60
#                 newfence: 4 newprize: 24
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 10 fence: 14 prize: 140
#                 newfence: 6 newprize: 60
#          type: N size: 116 fence: 84 prize: 9744
#                 newfence: 64 newprize: 7424
#          type: Q size: 50 fence: 46 prize: 2300
#                 newfence: 28 newprize: 1400
#          type: E size: 14 fence: 20 prize: 280
#                 newfence: 14 newprize: 196
#          type: G size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: D size: 18 fence: 22 prize: 396
#                 newfence: 16 newprize: 288
#          type: S size: 19 fence: 28 prize: 532
#                 newfence: 16 newprize: 304
#          type: C size: 30 fence: 36 prize: 1080
#                 newfence: 22 newprize: 660
#          type: Y size: 8 fence: 14 prize: 112
#                 newfence: 8 newprize: 64
#          type: U size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: N size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: P size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: D size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: M size: 8 fence: 16 prize: 128
#                 newfence: 8 newprize: 64
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Q size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: E size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: E size: 44 fence: 52 prize: 2288
#                 newfence: 38 newprize: 1672
#          type: R size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: K size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: N size: 39 fence: 52 prize: 2028
#                 newfence: 32 newprize: 1248
#          type: C size: 14 fence: 18 prize: 252
#                 newfence: 10 newprize: 140
#          type: X size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: A size: 143 fence: 150 prize: 21450
#                 newfence: 96 newprize: 13728
#          type: D size: 28 fence: 34 prize: 952
#                 newfence: 24 newprize: 672
#          type: C size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 44 fence: 38 prize: 1672
#                 newfence: 22 newprize: 968
#          type: X size: 73 fence: 68 prize: 4964
#                 newfence: 40 newprize: 2920
#          type: J size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: J size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: X size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: H size: 97 fence: 90 prize: 8730
#                 newfence: 50 newprize: 4850
#          type: N size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: G size: 81 fence: 64 prize: 5184
#                 newfence: 40 newprize: 3240
#          type: F size: 4 fence: 8 prize: 32
#                 newfence: 4 newprize: 16
#          type: H size: 122 fence: 74 prize: 9028
#                 newfence: 46 newprize: 5612
#          type: W size: 58 fence: 56 prize: 3248
#                 newfence: 34 newprize: 1972
#          type: E size: 115 fence: 96 prize: 11040
#                 newfence: 60 newprize: 6900
#          type: R size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: F size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: W size: 83 fence: 66 prize: 5478
#                 newfence: 38 newprize: 3154
#          type: G size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 138 fence: 80 prize: 11040
#                 newfence: 54 newprize: 7452
#          type: B size: 26 fence: 28 prize: 728
#                 newfence: 18 newprize: 468
#          type: T size: 130 fence: 88 prize: 11440
#                 newfence: 58 newprize: 7540
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: J size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 75 fence: 76 prize: 5700
#                 newfence: 50 newprize: 3750
#          type: C size: 4 fence: 8 prize: 32
#                 newfence: 4 newprize: 16
#          type: P size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Y size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: J size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: H size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: E size: 78 fence: 78 prize: 6084
#                 newfence: 40 newprize: 3120
#          type: P size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: V size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: K size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: P size: 77 fence: 64 prize: 4928
#                 newfence: 46 newprize: 3542
#          type: F size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 86 fence: 72 prize: 6192
#                 newfence: 50 newprize: 4300
#          type: K size: 120 fence: 56 prize: 6720
#                 newfence: 10 newprize: 1200
#          type: H size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: O size: 52 fence: 50 prize: 2600
#                 newfence: 30 newprize: 1560
#          type: I size: 18 fence: 24 prize: 432
#                 newfence: 16 newprize: 288
#          type: J size: 71 fence: 36 prize: 2556
#                 newfence: 8 newprize: 568
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: W size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Z size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: N size: 107 fence: 80 prize: 8560
#                 newfence: 46 newprize: 4922
#          type: F size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: P size: 100 fence: 74 prize: 7400
#                 newfence: 46 newprize: 4600
#          type: V size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: G size: 26 fence: 34 prize: 884
#                 newfence: 16 newprize: 416
#          type: Y size: 53 fence: 44 prize: 2332
#                 newfence: 30 newprize: 1590
#          type: W size: 55 fence: 48 prize: 2640
#                 newfence: 32 newprize: 1760
#          type: J size: 7 fence: 12 prize: 84
#                 newfence: 6 newprize: 42
#          type: C size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: Z size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: C size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: P size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: V size: 8 fence: 18 prize: 144
#                 newfence: 12 newprize: 96
#          type: V size: 84 fence: 92 prize: 7728
#                 newfence: 62 newprize: 5208
#          type: P size: 25 fence: 30 prize: 750
#                 newfence: 18 newprize: 450
#          type: Q size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: S size: 17 fence: 26 prize: 442
#                 newfence: 16 newprize: 272
#          type: J size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: T size: 130 fence: 88 prize: 11440
#                 newfence: 56 newprize: 7280
#          type: F size: 5 fence: 12 prize: 60
#                 newfence: 10 newprize: 50
#          type: Y size: 25 fence: 36 prize: 900
#                 newfence: 24 newprize: 600
#          type: G size: 85 fence: 56 prize: 4760
#                 newfence: 38 newprize: 3230
#          type: Z size: 13 fence: 22 prize: 286
#                 newfence: 14 newprize: 182
#          type: G size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: N size: 3 fence: 8 prize: 24
#                 newfence: 4 newprize: 12
#          type: A size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: N size: 54 fence: 48 prize: 2592
#                 newfence: 32 newprize: 1728
#          type: W size: 70 fence: 52 prize: 3640
#                 newfence: 36 newprize: 2520
#          type: A size: 113 fence: 90 prize: 10170
#                 newfence: 66 newprize: 7458
#          type: O size: 91 fence: 66 prize: 6006
#                 newfence: 44 newprize: 4004
#          type: V size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: V size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: O size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: B size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 104 fence: 70 prize: 7280
#                 newfence: 36 newprize: 3744
#          type: H size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 6 fence: 14 prize: 84
#                 newfence: 8 newprize: 48
#          type: J size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: D size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: A size: 3 fence: 8 prize: 24
#                 newfence: 4 newprize: 12
#          type: G size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: X size: 117 fence: 62 prize: 7254
#                 newfence: 36 newprize: 4212
#          type: Q size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: R size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: B size: 15 fence: 24 prize: 360
#                 newfence: 14 newprize: 210
#          type: L size: 58 fence: 48 prize: 2784
#                 newfence: 34 newprize: 1972
#          type: F size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: R size: 4 fence: 8 prize: 32
#                 newfence: 4 newprize: 16
#          type: K size: 121 fence: 82 prize: 9922
#                 newfence: 52 newprize: 6292
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: L size: 99 fence: 58 prize: 5742
#                 newfence: 30 newprize: 2970
#          type: Z size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: B size: 6 fence: 12 prize: 72
#                 newfence: 8 newprize: 48
#          type: X size: 6 fence: 14 prize: 84
#                 newfence: 8 newprize: 48
#          type: P size: 40 fence: 34 prize: 1360
#                 newfence: 20 newprize: 800
#          type: F size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: H size: 4 fence: 10 prize: 40
#                 newfence: 8 newprize: 32
#          type: V size: 5 fence: 10 prize: 50
#                 newfence: 6 newprize: 30
#          type: J size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: E size: 52 fence: 52 prize: 2704
#                 newfence: 24 newprize: 1248
#          type: T size: 69 fence: 60 prize: 4140
#                 newfence: 40 newprize: 2760
#          type: P size: 173 fence: 60 prize: 10380
#                 newfence: 12 newprize: 2076
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: R size: 10 fence: 18 prize: 180
#                 newfence: 10 newprize: 100
#          type: P size: 5 fence: 10 prize: 50
#                 newfence: 6 newprize: 30
#          type: L size: 69 fence: 62 prize: 4278
#                 newfence: 36 newprize: 2484
#          type: Q size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: L size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: B size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: O size: 5 fence: 10 prize: 50
#                 newfence: 6 newprize: 30
#          type: F size: 22 fence: 34 prize: 748
#                 newfence: 20 newprize: 440
#          type: K size: 26 fence: 32 prize: 832
#                 newfence: 20 newprize: 520
#          type: V size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: M size: 23 fence: 24 prize: 552
#                 newfence: 6 newprize: 138
#          type: T size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: F size: 26 fence: 34 prize: 884
#                 newfence: 24 newprize: 624
#          type: Z size: 7 fence: 12 prize: 84
#                 newfence: 6 newprize: 42
#          type: D size: 85 fence: 60 prize: 5100
#                 newfence: 42 newprize: 3570
#          type: G size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: B size: 42 fence: 40 prize: 1680
#                 newfence: 30 newprize: 1260
#          type: E size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: P size: 136 fence: 64 prize: 8704
#                 newfence: 14 newprize: 1904
#          type: F size: 85 fence: 72 prize: 6120
#                 newfence: 48 newprize: 4080
#          type: I size: 55 fence: 46 prize: 2530
#                 newfence: 28 newprize: 1540
#          type: Q size: 79 fence: 72 prize: 5688
#                 newfence: 46 newprize: 3634
#          type: S size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: D size: 101 fence: 56 prize: 5656
#                 newfence: 12 newprize: 1212
#          type: Z size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: K size: 144 fence: 110 prize: 15840
#                 newfence: 76 newprize: 10944
#          type: Z size: 9 fence: 18 prize: 162
#                 newfence: 8 newprize: 72
#          type: U size: 116 fence: 74 prize: 8584
#                 newfence: 32 newprize: 3712
#          type: O size: 4 fence: 10 prize: 40
#                 newfence: 4 newprize: 16
#          type: I size: 52 fence: 46 prize: 2392
#                 newfence: 26 newprize: 1352
#          type: A size: 252 fence: 158 prize: 39816
#                 newfence: 98 newprize: 24696
#          type: H size: 3 fence: 8 prize: 24
#                 newfence: 4 newprize: 12
#          type: M size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: A size: 24 fence: 28 prize: 672
#                 newfence: 24 newprize: 576
#          type: N size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: M size: 4 fence: 8 prize: 32
#                 newfence: 4 newprize: 16
#          type: M size: 6 fence: 10 prize: 60
#                 newfence: 4 newprize: 24
#          type: Y size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: N size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: D size: 4 fence: 10 prize: 40
#                 newfence: 6 newprize: 24
#          type: B size: 105 fence: 68 prize: 7140
#                 newfence: 44 newprize: 4620
#          type: E size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: T size: 3 fence: 8 prize: 24
#                 newfence: 4 newprize: 12
#          type: A size: 15 fence: 24 prize: 360
#                 newfence: 16 newprize: 240
#          type: F size: 7 fence: 12 prize: 84
#                 newfence: 6 newprize: 42
#          type: C size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: L size: 79 fence: 56 prize: 4424
#                 newfence: 34 newprize: 2686
#          type: G size: 68 fence: 48 prize: 3264
#                 newfence: 28 newprize: 1904
#          type: V size: 24 fence: 24 prize: 576
#                 newfence: 16 newprize: 384
#          type: E size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: K size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: B size: 27 fence: 32 prize: 864
#                 newfence: 14 newprize: 378
#          type: O size: 45 fence: 40 prize: 1800
#                 newfence: 30 newprize: 1350
#          type: C size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 107 fence: 84 prize: 8988
#                 newfence: 52 newprize: 5564
#          type: F size: 12 fence: 18 prize: 216
#                 newfence: 10 newprize: 120
#          type: E size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: T size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: P size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: F size: 16 fence: 20 prize: 320
#                 newfence: 4 newprize: 64
#          type: X size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Y size: 55 fence: 42 prize: 2310
#                 newfence: 28 newprize: 1540
#          type: W size: 11 fence: 18 prize: 198
#                 newfence: 10 newprize: 110
#          type: D size: 20 fence: 26 prize: 520
#                 newfence: 18 newprize: 360
#          type: W size: 60 fence: 54 prize: 3240
#                 newfence: 28 newprize: 1680
#          type: L size: 34 fence: 32 prize: 1088
#                 newfence: 20 newprize: 680
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: F size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: N size: 50 fence: 48 prize: 2400
#                 newfence: 34 newprize: 1700
#          type: B size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: R size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: K size: 82 fence: 76 prize: 6232
#                 newfence: 50 newprize: 4100
#          type: V size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: H size: 6 fence: 14 prize: 84
#                 newfence: 10 newprize: 60
#          type: N size: 35 fence: 38 prize: 1330
#                 newfence: 24 newprize: 840
#          type: J size: 5 fence: 10 prize: 50
#                 newfence: 6 newprize: 30
#          type: R size: 19 fence: 22 prize: 418
#                 newfence: 8 newprize: 152
#          type: H size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: C size: 103 fence: 94 prize: 9682
#                 newfence: 56 newprize: 5768
#          type: V size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: X size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: X size: 7 fence: 14 prize: 98
#                 newfence: 12 newprize: 84
#          type: Z size: 47 fence: 44 prize: 2068
#                 newfence: 28 newprize: 1316
#          type: J size: 4 fence: 10 prize: 40
#                 newfence: 8 newprize: 32
#          type: Z size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: J size: 32 fence: 32 prize: 1024
#                 newfence: 20 newprize: 640
#          type: Q size: 52 fence: 50 prize: 2600
#                 newfence: 28 newprize: 1456
#          type: D size: 31 fence: 36 prize: 1116
#                 newfence: 26 newprize: 806
#          type: X size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: I size: 21 fence: 30 prize: 630
#                 newfence: 16 newprize: 336
#          type: V size: 142 fence: 78 prize: 11076
#                 newfence: 54 newprize: 7668
#          type: L size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: F size: 4 fence: 8 prize: 32
#                 newfence: 4 newprize: 16
#          type: H size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: Z size: 56 fence: 40 prize: 2240
#                 newfence: 24 newprize: 1344
#          type: U size: 16 fence: 24 prize: 384
#                 newfence: 14 newprize: 224
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: A size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: M size: 129 fence: 74 prize: 9546
#                 newfence: 44 newprize: 5676
#          type: R size: 6 fence: 12 prize: 72
#                 newfence: 8 newprize: 48
#          type: Z size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: E size: 6 fence: 12 prize: 72
#                 newfence: 8 newprize: 48
#          type: K size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 27 fence: 30 prize: 810
#                 newfence: 16 newprize: 432
#          type: D size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: E size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: U size: 97 fence: 72 prize: 6984
#                 newfence: 46 newprize: 4462
#          type: Q size: 7 fence: 12 prize: 84
#                 newfence: 8 newprize: 56
#          type: P size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: Z size: 119 fence: 72 prize: 8568
#                 newfence: 46 newprize: 5474
#          type: Y size: 41 fence: 42 prize: 1722
#                 newfence: 28 newprize: 1148
#          type: C size: 136 fence: 76 prize: 10336
#                 newfence: 42 newprize: 5712
#          type: K size: 71 fence: 60 prize: 4260
#                 newfence: 40 newprize: 2840
#          type: Q size: 3 fence: 8 prize: 24
#                 newfence: 4 newprize: 12
#          type: N size: 6 fence: 10 prize: 60
#                 newfence: 4 newprize: 24
#          type: D size: 50 fence: 48 prize: 2400
#                 newfence: 32 newprize: 1600
#          type: S size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: B size: 96 fence: 64 prize: 6144
#                 newfence: 42 newprize: 4032
#          type: G size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: Q size: 26 fence: 32 prize: 832
#                 newfence: 20 newprize: 520
#          type: X size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: W size: 9 fence: 18 prize: 162
#                 newfence: 14 newprize: 126
#          type: L size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: G size: 61 fence: 48 prize: 2928
#                 newfence: 36 newprize: 2196
#          type: B size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: E size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Z size: 57 fence: 56 prize: 3192
#                 newfence: 34 newprize: 1938
#          type: P size: 118 fence: 76 prize: 8968
#                 newfence: 56 newprize: 6608
#          type: T size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: A size: 10 fence: 20 prize: 200
#                 newfence: 14 newprize: 140
#          type: I size: 16 fence: 28 prize: 448
#                 newfence: 18 newprize: 288
#          type: M size: 11 fence: 22 prize: 242
#                 newfence: 16 newprize: 176
#          type: A size: 126 fence: 70 prize: 8820
#                 newfence: 42 newprize: 5292
#          type: P size: 124 fence: 74 prize: 9176
#                 newfence: 48 newprize: 5952
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: T size: 4 fence: 10 prize: 40
#                 newfence: 4 newprize: 16
#          type: F size: 79 fence: 66 prize: 5214
#                 newfence: 38 newprize: 3002
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: W size: 17 fence: 26 prize: 442
#                 newfence: 18 newprize: 306
#          type: Y size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: B size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: H size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 10 fence: 18 prize: 180
#                 newfence: 12 newprize: 120
#          type: Y size: 25 fence: 36 prize: 900
#                 newfence: 24 newprize: 600
#          type: P size: 49 fence: 48 prize: 2352
#                 newfence: 30 newprize: 1470
#          type: R size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: T size: 19 fence: 24 prize: 456
#                 newfence: 18 newprize: 342
#          type: H size: 33 fence: 38 prize: 1254
#                 newfence: 28 newprize: 924
#          type: T size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: H size: 21 fence: 32 prize: 672
#                 newfence: 22 newprize: 462
#          type: D size: 88 fence: 68 prize: 5984
#                 newfence: 42 newprize: 3696
#          type: E size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: X size: 170 fence: 100 prize: 17000
#                 newfence: 62 newprize: 10540
#          type: N size: 6 fence: 12 prize: 72
#                 newfence: 6 newprize: 36
#          type: U size: 90 fence: 84 prize: 7560
#                 newfence: 60 newprize: 5400
#          type: S size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: B size: 142 fence: 152 prize: 21584
#                 newfence: 96 newprize: 13632
#          type: X size: 105 fence: 86 prize: 9030
#                 newfence: 58 newprize: 6090
#          type: S size: 8 fence: 14 prize: 112
#                 newfence: 8 newprize: 64
#          type: B size: 61 fence: 50 prize: 3050
#                 newfence: 28 newprize: 1708
#          type: B size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: G size: 6 fence: 12 prize: 72
#                 newfence: 8 newprize: 48
#          type: M size: 177 fence: 88 prize: 15576
#                 newfence: 32 newprize: 5664
#          type: J size: 153 fence: 86 prize: 13158
#                 newfence: 56 newprize: 8568
#          type: N size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: X size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: O size: 18 fence: 32 prize: 576
#                 newfence: 24 newprize: 432
#          type: D size: 71 fence: 60 prize: 4260
#                 newfence: 40 newprize: 2840
#          type: R size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: O size: 14 fence: 26 prize: 364
#                 newfence: 14 newprize: 196
#          type: G size: 282 fence: 132 prize: 37224
#                 newfence: 82 newprize: 23124
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: W size: 38 fence: 36 prize: 1368
#                 newfence: 26 newprize: 988
#          type: R size: 44 fence: 56 prize: 2464
#                 newfence: 32 newprize: 1408
#          type: P size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: O size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: H size: 76 fence: 60 prize: 4560
#                 newfence: 34 newprize: 2584
#          type: H size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: J size: 94 fence: 54 prize: 5076
#                 newfence: 32 newprize: 3008
#          type: E size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Q size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 4 fence: 10 prize: 40
#                 newfence: 8 newprize: 32
#          type: K size: 108 fence: 60 prize: 6480
#                 newfence: 30 newprize: 3240
#          type: W size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: K size: 20 fence: 28 prize: 560
#                 newfence: 18 newprize: 360
#          type: W size: 31 fence: 34 prize: 1054
#                 newfence: 22 newprize: 682
#          type: I size: 179 fence: 122 prize: 21838
#                 newfence: 70 newprize: 12530
#          type: G size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: B size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: J size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: H size: 41 fence: 44 prize: 1804
#                 newfence: 28 newprize: 1148
#          type: J size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: V size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Q size: 127 fence: 76 prize: 9652
#                 newfence: 44 newprize: 5588
#          type: T size: 109 fence: 58 prize: 6322
#                 newfence: 14 newprize: 1526
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 12 fence: 22 prize: 264
#                 newfence: 14 newprize: 168
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Q size: 137 fence: 70 prize: 9590
#                 newfence: 34 newprize: 4658
#          type: G size: 101 fence: 80 prize: 8080
#                 newfence: 52 newprize: 5252
#          type: T size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: K size: 12 fence: 14 prize: 168
#                 newfence: 4 newprize: 48
#          type: B size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: P size: 172 fence: 144 prize: 24768
#                 newfence: 96 newprize: 16512
#          type: H size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: Q size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: E size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: V size: 238 fence: 116 prize: 27608
#                 newfence: 42 newprize: 9996
#          type: R size: 4 fence: 8 prize: 32
#                 newfence: 4 newprize: 16
#          type: E size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: E size: 16 fence: 20 prize: 320
#                 newfence: 14 newprize: 224
#          type: J size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: O size: 29 fence: 26 prize: 754
#                 newfence: 16 newprize: 464
#          type: J size: 84 fence: 64 prize: 5376
#                 newfence: 42 newprize: 3528
#          type: Q size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: H size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: E size: 16 fence: 22 prize: 352
#                 newfence: 14 newprize: 224
#          type: S size: 105 fence: 80 prize: 8400
#                 newfence: 44 newprize: 4620
#          type: O size: 22 fence: 28 prize: 616
#                 newfence: 16 newprize: 352
#          type: A size: 5 fence: 12 prize: 60
#                 newfence: 6 newprize: 30
#          type: L size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: V size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: K size: 128 fence: 70 prize: 8960
#                 newfence: 46 newprize: 5888
#          type: F size: 42 fence: 38 prize: 1596
#                 newfence: 22 newprize: 924
#          type: Q size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: T size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: B size: 130 fence: 82 prize: 10660
#                 newfence: 54 newprize: 7020
#          type: L size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 107 fence: 82 prize: 8774
#                 newfence: 50 newprize: 5350
#          type: T size: 141 fence: 78 prize: 10998
#                 newfence: 40 newprize: 5640
#          type: D size: 3 fence: 8 prize: 24
#                 newfence: 4 newprize: 12
#          type: J size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: Q size: 43 fence: 48 prize: 2064
#                 newfence: 28 newprize: 1204
#          type: J size: 306 fence: 102 prize: 31212
#                 newfence: 18 newprize: 5508
#          type: Z size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 59 fence: 52 prize: 3068
#                 newfence: 34 newprize: 2006
#          type: O size: 36 fence: 36 prize: 1296
#                 newfence: 26 newprize: 936
#          type: R size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: R size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: I size: 8 fence: 14 prize: 112
#                 newfence: 8 newprize: 64
#          type: O size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: W size: 4 fence: 8 prize: 32
#                 newfence: 4 newprize: 16
#          type: J size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Y size: 5 fence: 12 prize: 60
#                 newfence: 6 newprize: 30
#          type: S size: 111 fence: 64 prize: 7104
#                 newfence: 38 newprize: 4218
#          type: U size: 62 fence: 46 prize: 2852
#                 newfence: 26 newprize: 1612
#          type: O size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: R size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: X size: 33 fence: 36 prize: 1188
#                 newfence: 22 newprize: 726
#          type: D size: 57 fence: 46 prize: 2622
#                 newfence: 36 newprize: 2052
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: X size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: H size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: Q size: 3 fence: 8 prize: 24
#                 newfence: 4 newprize: 12
#          type: Y size: 112 fence: 72 prize: 8064
#                 newfence: 44 newprize: 4928
#          type: R size: 3 fence: 8 prize: 24
#                 newfence: 4 newprize: 12
#          type: O size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: N size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: G size: 115 fence: 66 prize: 7590
#                 newfence: 38 newprize: 4370
#          type: P size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: F size: 12 fence: 18 prize: 216
#                 newfence: 10 newprize: 120
#          type: W size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Q size: 5 fence: 12 prize: 60
#                 newfence: 6 newprize: 30
#          type: T size: 5 fence: 12 prize: 60
#                 newfence: 8 newprize: 40
#          type: F size: 16 fence: 22 prize: 352
#                 newfence: 16 newprize: 256
#          type: G size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: K size: 4 fence: 8 prize: 32
#                 newfence: 4 newprize: 16
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 14 fence: 20 prize: 280
#                 newfence: 10 newprize: 140
#          type: C size: 6 fence: 14 prize: 84
#                 newfence: 10 newprize: 60
#          type: L size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: G size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: D size: 13 fence: 20 prize: 260
#                 newfence: 8 newprize: 104
#          type: A size: 98 fence: 74 prize: 7252
#                 newfence: 46 newprize: 4508
#          type: A size: 113 fence: 68 prize: 7684
#                 newfence: 42 newprize: 4746
#          type: V size: 41 fence: 38 prize: 1558
#                 newfence: 22 newprize: 902
#          type: N size: 110 fence: 64 prize: 7040
#                 newfence: 42 newprize: 4620
#          type: P size: 15 fence: 24 prize: 360
#                 newfence: 16 newprize: 240
#          type: R size: 102 fence: 72 prize: 7344
#                 newfence: 28 newprize: 2856
#          type: D size: 5 fence: 12 prize: 60
#                 newfence: 6 newprize: 30
#          type: O size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: B size: 56 fence: 54 prize: 3024
#                 newfence: 38 newprize: 2128
#          type: Z size: 17 fence: 24 prize: 408
#                 newfence: 14 newprize: 238
#          type: P size: 5 fence: 12 prize: 60
#                 newfence: 6 newprize: 30
#          type: Z size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: C size: 106 fence: 110 prize: 11660
#                 newfence: 70 newprize: 7420
#          type: E size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: L size: 81 fence: 60 prize: 4860
#                 newfence: 38 newprize: 3078
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: L size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: W size: 25 fence: 32 prize: 800
#                 newfence: 22 newprize: 550
#          type: Y size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: P size: 7 fence: 16 prize: 112
#                 newfence: 10 newprize: 70
#          type: W size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: F size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: R size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: E size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: P size: 3 fence: 8 prize: 24
#                 newfence: 4 newprize: 12
#          type: W size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Q size: 76 fence: 62 prize: 4712
#                 newfence: 42 newprize: 3192
#          type: E size: 123 fence: 88 prize: 10824
#                 newfence: 54 newprize: 6642
#          type: R size: 26 fence: 28 prize: 728
#                 newfence: 16 newprize: 416
#          type: C size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: T size: 45 fence: 48 prize: 2160
#                 newfence: 28 newprize: 1260
#          type: W size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: M size: 5 fence: 12 prize: 60
#                 newfence: 10 newprize: 50
#          type: O size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: T size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: D size: 75 fence: 62 prize: 4650
#                 newfence: 44 newprize: 3300
#          type: H size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: F size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: W size: 107 fence: 78 prize: 8346
#                 newfence: 52 newprize: 5564
#          type: M size: 13 fence: 22 prize: 286
#                 newfence: 14 newprize: 182
#          type: M size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: Q size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Y size: 18 fence: 28 prize: 504
#                 newfence: 20 newprize: 360
#          type: L size: 232 fence: 134 prize: 31088
#                 newfence: 94 newprize: 21808
#          type: G size: 141 fence: 70 prize: 9870
#                 newfence: 38 newprize: 5358
#          type: W size: 49 fence: 58 prize: 2842
#                 newfence: 42 newprize: 2058
#          type: V size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: O size: 60 fence: 42 prize: 2520
#                 newfence: 20 newprize: 1200
#          type: X size: 66 fence: 54 prize: 3564
#                 newfence: 30 newprize: 1980
#          type: R size: 12 fence: 16 prize: 192
#                 newfence: 8 newprize: 96
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: F size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: F size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: P size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: E size: 21 fence: 26 prize: 546
#                 newfence: 14 newprize: 294
#          type: M size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: W size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: N size: 30 fence: 36 prize: 1080
#                 newfence: 22 newprize: 660
#          type: V size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: J size: 11 fence: 20 prize: 220
#                 newfence: 14 newprize: 154
#          type: V size: 77 fence: 72 prize: 5544
#                 newfence: 46 newprize: 3542
#          type: O size: 42 fence: 52 prize: 2184
#                 newfence: 38 newprize: 1596
#          type: B size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: G size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: C size: 126 fence: 100 prize: 12600
#                 newfence: 76 newprize: 9576
#          type: L size: 13 fence: 20 prize: 260
#                 newfence: 12 newprize: 156
#          type: U size: 156 fence: 84 prize: 13104
#                 newfence: 48 newprize: 7488
#          type: W size: 8 fence: 18 prize: 144
#                 newfence: 12 newprize: 96
#          type: L size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: U size: 92 fence: 58 prize: 5336
#                 newfence: 38 newprize: 3496
#          type: P size: 84 fence: 72 prize: 6048
#                 newfence: 46 newprize: 3864
#          type: C size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: X size: 42 fence: 52 prize: 2184
#                 newfence: 34 newprize: 1428
#          type: P size: 146 fence: 84 prize: 12264
#                 newfence: 56 newprize: 8176
#          type: U size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Y size: 40 fence: 50 prize: 2000
#                 newfence: 36 newprize: 1440
#          type: I size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: A size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: D size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Q size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: F size: 116 fence: 76 prize: 8816
#                 newfence: 42 newprize: 4872
#          type: U size: 61 fence: 54 prize: 3294
#                 newfence: 34 newprize: 2074
#          type: S size: 7 fence: 16 prize: 112
#                 newfence: 14 newprize: 98
#          type: O size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: I size: 59 fence: 50 prize: 2950
#                 newfence: 34 newprize: 2006
#          type: G size: 116 fence: 94 prize: 10904
#                 newfence: 48 newprize: 5568
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Q size: 145 fence: 80 prize: 11600
#                 newfence: 38 newprize: 5510
#          type: M size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: U size: 126 fence: 82 prize: 10332
#                 newfence: 46 newprize: 5796
#          type: T size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: N size: 20 fence: 22 prize: 440
#                 newfence: 12 newprize: 240
#          type: F size: 4 fence: 10 prize: 40
#                 newfence: 8 newprize: 32
#          type: R size: 3 fence: 8 prize: 24
#                 newfence: 4 newprize: 12
#          type: E size: 4 fence: 10 prize: 40
#                 newfence: 6 newprize: 24
#          type: H size: 57 fence: 50 prize: 2850
#                 newfence: 36 newprize: 2052
#          type: K size: 106 fence: 74 prize: 7844
#                 newfence: 54 newprize: 5724
#          type: Q size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 4 fence: 10 prize: 40
#                 newfence: 6 newprize: 24
#          type: L size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: E size: 142 fence: 90 prize: 12780
#                 newfence: 60 newprize: 8520
#          type: W size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: W size: 10 fence: 18 prize: 180
#                 newfence: 12 newprize: 120
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: P size: 106 fence: 82 prize: 8692
#                 newfence: 38 newprize: 4028
#          type: S size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: R size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: S size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: C size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: R size: 27 fence: 26 prize: 702
#                 newfence: 12 newprize: 324
#          type: G size: 10 fence: 16 prize: 160
#                 newfence: 12 newprize: 120
#          type: K size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: G size: 3 fence: 8 prize: 24
#                 newfence: 6 newprize: 18
#          type: T size: 7 fence: 14 prize: 98
#                 newfence: 10 newprize: 70
#          type: T size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: H size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: D size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: A size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: S size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: W size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: B size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: K size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: F size: 12 fence: 18 prize: 216
#                 newfence: 10 newprize: 120
#          type: X size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Q size: 13 fence: 20 prize: 260
#                 newfence: 10 newprize: 130
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: N size: 9 fence: 14 prize: 126
#                 newfence: 6 newprize: 54
#          type: I size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: Z size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
#          type: C size: 2 fence: 6 prize: 12
#                 newfence: 4 newprize: 8
#          type: M size: 1 fence: 4 prize: 4
#                 newfence: 4 newprize: 4
# total prize:  1377008
# new total prize:  815788
